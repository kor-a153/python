# %%
# 65 -> A
chr(65)

# "A" -> 65
ord("A")
# Out:
# 65

# %%
password = "test123"
for i in password :
    print(chr(ord(i) * 100), end= "")
# Out:
# ⵐ❴ⳬⵐጤᎈᏬ

# %%
expression = input("수식을 입력하세요. ex)10+10\n")
# Out:
# 수식을 입력하세요. ex)10+10
#  10*40

# %%
eval(expression)
# Out:
# 400

# %%
data1 = format(10000000, ",")
print(data1)
data2 = format(10000000, ",")
print(data2)

print(type(data1))
print(type(data2))
# Out:
# 10,000,000
# 10,000,000
# <class 'str'>
# <class 'str'>

# %%
divmod(10,3)
# Out:
# (3, 1)

# %%
# 오사오입
# 값이 1~4까지일때 버림
# 값이 5일때
# 앞이 짝수면 버림 
# 앞이 홀수면 올림
print(round(1.5))
print(round(2.5))
print(round(3.5))
print(round(4.5))
# Out:
# 2
# 2
# 4
# 4

# %% [markdown]
# ### 문자열 함수

# %%
# count
print("abcdeed".count( "e"))
# Out:
# 2

# %%
# find
# 첫번째 e의 인덱스 번호
print("abcdeed".find( "e"))
# Out:
# 4

# %%
# 마지막 E의 인덱스 번호
print("fdgjklsdeefgsdffds".rfind("e"))
# Out:
# -------------------------------------------------------------------------
# TypeError                               Traceback (most recent call last)
# Cell In[21], line 2
#       1 # 마지막 E의 인덱스 번호
# ----> 2 print("fdgjklsdeefgsdffds".rfind("e"))
#
# TypeError: 'int' object is not callable

# %%
"a".upper()
# Out:
# 'A'

# %%
'A'.lower()
# Out:
# 'a'

# %%
# 파스칼 표기법으로 변환
"apple".capitalize()
# Out:
# 'Apple'

# %%
# 문자열 , 리스트
print("a".join("b"))
print("apple".join("b"))
print("합쳐조라".join("b"))
# Out:
# -------------------------------------------------------------------------
# TypeError                               Traceback (most recent call last)
# Cell In[25], line 2
#       1 # 문자열 , 리스트
# ----> 2 print("a".join("b"))
#       3 print("apple".join("b"))
#       4 print("합쳐조라".join("b"))
#
# TypeError: 'int' object is not callable

# %%
li4 = [str((i+1)*10 for i in range(5))]

# %%
", ".join(li4)
# Out:
# '<generator object <genexpr> at 0x0000027A46D1B440>'

# %%
str1 = "Life is to short"

# %%
# 2.  값이 바뀌면 새롭게 반환
# 새로운 문자열 리턴
str1.replace("short" , "Long")
# Out:
# 'Life is to Long'

# %%
str1
# Out:
# 'Life is to short'

# %%
# 문자열 내부의 값이 정수로만 이루어져 있는지 확인 -> bool
"10".isdigit()
# Out:
# True

# %%
"10r".isdigit()
# Out:
# False

# %%
num1 = input("정수를 입력하세요")
# Out:
# 정수를 입력하세요 ㅁㄴㅇㅁㄴㅇ

# %%
if num1.isdigit():
    num1 = int(num1)
else:
    print("정신차려")
# Out:
# -------------------------------------------------------------------------
# TypeError                               Traceback (most recent call last)
# Cell In[42], line 4
#       1 if num1.isdigit():
#       2     num1 = int(num1)
#       3 else:
# ----> 4     print("정신차려")
#
# TypeError: 'int' object is not callable

# %%
# 문자가 포함되었는지 확인하는 메서드
num1.isalpha()
# Out:
# True

# %%
data3 = "***********da*******ta****da"

# %%
print(data3.replace("*",""))
# Out:
# -------------------------------------------------------------------------
# TypeError                               Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 print(data3.replace("*",""))
#
# TypeError: 'int' object is not callable

# %%
data3[data3.find("d"):]
# Out:
# 'da*******ta****da'

# %%
data3.lstrip("*")
# Out:
# 'da*******ta****da'

# %%
data3.rstrip("*")
# Out:
# '***********da*******ta****da'

# %%
data3.strip("*")
# Out:
# 'da*******ta****da'

# %%
"12312.421431.242.14.214213123.241".split(".")
# Out:
# ['12312', '421431', '242', '14', '214213123', '241']

# %%
names = "짱구","하영","수지"
score = 20 ,40 , 60
address = "떡잎마을" , "강남", "압구정"

# %%
for i in zip(names, score,address) :
    print(i)
# Out:
# -------------------------------------------------------------------------
# TypeError                               Traceback (most recent call last)
# Cell In[60], line 2
#       1 for i in zip(names, score,address) :
# ----> 2     print(i)
#
# TypeError: 'int' object is not callable
