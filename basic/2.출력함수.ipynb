# %%
# 주석 : ctrl +/
# "", '' 을 구분하지 않음
print('Hello,World😊')
# Out:
# Hello,World😊

# %%
# 권장
print ("\'홍길동\'님")
# Out:
# '홍길동'님

# %%
print("a""b")
# Out:
# ab

# %%
print ('b'"a")
# Out:
# ba

# %%
# doc string
print ("""메롱""")
# Out:
# 메롱

# %%
# 한줄씩 인식하는 인터프리터 언어라서 아래는 에ㄹ가 남
# 따라서 엔터치면 안됨
print ("
       a
")
# Out:
#   Cell In[11], line 3
#     print ("
#            ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
print ("""
    엔터치고 싶으면 \'doc String을 사용해야한다. \'
""")
# Out:
#     엔터치고 싶으면 'doc String을 사용해야한다. '

# %%
# 제어문자
# \n : 줄바꿈
# \t : 탭
# \' : '
# \" : "
# \\ : \
print ("이름 : 홍길동 \n나이 :20살")
# Out:
# 이름 : 홍길동
# 나이 :20살

# %%
# print : 줄바꿈
print ("홍길동", end = "")
print ("안녕", end = "\n") #{default)
print ("하세요", end = "")
# Out:
# 홍길동안녕
# 하세요

# %%
print ("a","b","c",end=",")
# Out:
# a b c,

# %%
# 파이썬은 키워드가 없다.
a = 10
b = 10

# %%
# 동적 바인딩 언어
print (type(a))
# Out:
# <class 'int'>

# %%
print (a)
# Out:
# 10

# %%
a= 20
print(a)
# Out:
# 20

# %%
# f"" : 포맷 "{}" 스트링
# 문지열 내부에서 변수를 사용할수 있게 도와주는 문법
print (f"나이는 {a}살")
# Out:
# 나이는 20살

# %%
# r "" : 윈도우 환경에서 \ 또는 / 를 경로로 정확히 인식시키기 위한 문법
r"C:\back_0900_kyj\wewe"
# Out:
# 'C:\\back_0900_kyj\\wewe'
