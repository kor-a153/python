# %%
class User:
    name : str
    age : int
    phone : str
  
    
    def __init__ (self,name,age,phone):
        self.name =name
        self.age = age
        self.phone = phone

    # toStirng
    def __str__(self) :

# %%
print(User("홍길동", 20 ,"010-2348-9962"))
# Out:
# <__main__.User object at 0x00000260F9BB7010>

# %%
# 동물
# 이름, 나이, 먹이, 취미, 주인 , 성별

class Animal:

# %% [markdown]
# ## 연산자

# %%
# 회사원
class Employee(BaseModel):
    id: int
    name: str
    income: int

# %%
employee1_data1 = {
    "name" : "홍길동",
    "income" : 10000
}
employee1_data2 = {
    "name" : "이순신",
    "income" : 20000
}

employee1 = Employee(**employee_data1)
employee2 = Employee(**employee_data2)

# %%
print(emplooyee1)
print(emplooyee2)
print(student1)
print(student2)

# %%
student_data1 = {
    "id" : 1,
    "name" : "홍길동",
    "income" : 10000
}

# %%
print (student1)
print (student3)

# %%
print (Student.__eq__ (student1,student3))

# %%
class Student :
    def __init__(self,id,name):
        self.id = id
        self.name = name

    def __eq__(self,other):
        if self.__repr__() == other.__repr__():
            return True

        if isinstance(other,Student):
            return self.id == other == id

    return False

# %%
student4 =Student
