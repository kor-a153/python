# %%
# v1.0
# ChatModel
from langchain_core.prompts.few_shot import FewShotChatMessagePromptTemplate
from langchain_core.prompts.chat import ChatPromptTemplate

# %%
# import v1.0
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts.prompt import PromptTemplate
from langchain_core.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# LLM 모델
# FewShotPromptTemplate
from langchain_core.prompts.few_shot import FewShotPromptTemplate

# %% [markdown]
# ## FewShotPromptTemplate

# %%
examples = [
    
]

# %% [markdown]
# ## 2단계 : 예시용 프롬프트 템플릿 정의

# %%
examples = [
    {
        "country": "프랑스에 대해서 어떻게 알고 있나요?",
        "answer": """
            저는 이렇게 알고 있어요
            수도: 파리
            언어: 프랑스어
            음식: 와인과 치즈
            통화: 유로
        """
    },
    {
    "country": "일본에 대해서 어떻게 알고 있나요?",
    "answer": """
        저는 이렇게 알고 있어요
        수도: 도쿄
        언어: 일본어
        음식: 스시와 라멘
        통화: 엔
    """
    },
    {
        "country": "대한민국에 대해서 어떻게 알고 있나요?",
        "answer": """
            저는 이렇게 알고 있어요
            수도: 서울
            언어: 한국어
            음식: 김치와 불고기
            통화: 원
        """
    },
    {
    "country": "이탈리아에 대해서 어떻게 알고 있나요?",
    "answer": """
        저는 이렇게 알고 있어요
        수도: 로마
        언어: 이탈리아어
        음식: 피자와 파스타
        통화: 유로
    """
    }
]

# %% [markdown]
# ## 3단계 : FewShotPromptTemplate 생성 후 결합

# %%
prompt = FewShotPromptTemplate(
     # 질문
    example_prompt = example_prompt,
    # 예시
    examples =examples ,
    # 사용자의 질문
    suffix = "Human","{country}에 대해서 어떻게 알고 있어요 ?"
    input_variagles= ["country"]
)
# Out:
#   Cell In[15], line 7
#     suffix = "Human","{country}에 대해서 어떻게 알고 있어요 ?"
#                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
prompt = FewShotPromptTemplate(
    example_prompt=example_prompt,
    examples=examples,
    suffix="Human: {country}에 대해서 어떻게 알고 있어요?",
    input_variables=["country"]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 prompt = FewShotPromptTemplate(
# ----> 2     example_prompt=example_prompt,
#       3     examples=examples,
#       4     suffix="Human: {country}에 대해서 어떻게 알고 있어요?",
#       5     input_variables=["country"]
#
# NameError: name 'example_prompt' is not defined

# %%
chat = ChatOpenAI(temperature=0)

# %%
chain = prompt | chat

# %%
result = chain.invoke({
    "country" : "한국"
})

# %%
print(result.content)

# %% [markdown]
# ## FewShotExampleTemplate

# %%
examples = [
    {
        "country": "프랑스에 대해서 어떻게 알고 있나요?",
        "answer": """
            저는 이렇게 알고 있어요
            수도: 파리
            언어: 프랑스어
            음식: 와인과 치즈
            통화: 유로
        """
    },
    {
    "country": "일본에 대해서 어떻게 알고 있나요?",
    "answer": """
        저는 이렇게 알고 있어요
        수도: 도쿄
        언어: 일본어
        음식: 스시와 라멘
        통화: 엔
    """
    },
    {
        "country": "대한민국에 대해서 어떻게 알고 있나요?",
        "answer": """
            저는 이렇게 알고 있어요
            수도: 서울
            언어: 한국어
            음식: 김치와 불고기
            통화: 원
        """
    },
    {
    "country": "이탈리아에 대해서 어떻게 알고 있나요?",
    "answer": """
        저는 이렇게 알고 있어요
        수도: 로마
        언어: 이탈리아어
        음식: 피자와 파스타
        통화: 유로
    """
    }
]

# %%
## 2단계 예시용 프롬프트 템플릿 정의

# %%
example_prompt = ChatPromptTemplate.from_messages([
    ("Human" , "{country}에 대해서 어떻게 알고 있어요 ?")
    ("ai", "{answer}"),
])

# %%
prompt = FewShotChatMessagePromptTemplate(
    example_prompt = example_prompt,
    examples =examples
)

# %%
# final = prompt | chain

# %%
ChatPromptTemplate.from_message([
    ("system" , "당신은 지리학 전문가 입니다. 짧은 답변을 제공하세요.")
    example_prompt,
    ("human","{country}에 대해서 어떻게 알고 있어요?")
])

# %%
final_chain = final_chain | chat

# %%
result = final_chain.invoke ({
    "country":"일본"
})

# %%
print(result.content)

# %%
## LengthBasedExampleSelector 설계

# %%
# v1.0
from langchain_core.example_selectors.length_based import LengthBasedExampleSelector

# %%
examples = [
    {
        "country": "프랑스에 대해서 어떻게 알고 있나요?",
        "answer": """
            저는 이렇게 알고 있어요
            수도: 파리
            언어: 프랑스어
            음식: 와인과 치즈
            통화: 유로
        """
    },
    {
    "country": "일본에 대해서 어떻게 알고 있나요?",
    "answer": """
        저는 이렇게 알고 있어요
        수도: 도쿄
        언어: 일본어
        음식: 스시와 라멘
        통화: 엔
    """
    },
    {
        "country": "대한민국에 대해서 어떻게 알고 있나요?",
        "answer": """
            저는 이렇게 알고 있어요
            수도: 서울
            언어: 한국어
            음식: 김치와 불고기
            통화: 원
        """
    },
    {
    "country": "이탈리아에 대해서 어떻게 알고 있나요?",
    "answer": """
        저는 이렇게 알고 있어요
        수도: 로마
        언어: 이탈리아어
        음식: 피자와 파스타
        통화: 유로
    """
    }
]

# %%
example_prompt = PromptTemplate.from_template("Human: {country} \n AI: {answer}")

# %% [markdown]
# ## Selector 연결

# %%
example_selector = LengthBasedExampleSelector(
    examples = examples,
    example_prompt=example_prompt,
    # 예제의 양 허용 (토큰 개수)
    max_length=10
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 example_selector = LengthBasedExampleSelector(
#       2     examples = examples,
#       3     example_prompt=example_prompt,
#       4     # 예제의 양 허용 (토큰 개수)
#
# NameError: name 'LengthBasedExampleSelector' is not defined

# %%
prompt = FewShotPromptTemplate(
    example_prompt = example_prompt,
    example_selector = example_slector,
    suffix="Human:{country}에 대해서 어떻게 알고 있나요?"
    input_variagles =["country"]
)
# Out:
#   Cell In[18], line 4
#     suffix="Human:{country}에 대해서 어떻게 알고 있나요?"
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
prompt.format(**{
    "country":"브라질"
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 prompt.format(**{
#       2     "country":"브라질"
#       3 })
#
# NameError: name 'prompt' is not defined

# %%
final_chain = prompt | chat

# %%
result = final_chain.invoke({
    "country":"독일"
})

# %%
print(result.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print(result.content)
#       2
#
# NameError: name 'result' is not defined

# %% [markdown]
# ## Chat 모델 (LengthBasedExampleSelector)

# %%
examples = [
    {
        "country": "프랑스에 대해서 어떻게 알고 있나요?",
        "answer": """
            저는 이렇게 알고 있어요
            수도: 파리
            언어: 프랑스어
            음식: 와인과 치즈
            통화: 유로
        """
    },
    {
    "country": "일본에 대해서 어떻게 알고 있나요?",
    "answer": """
        저는 이렇게 알고 있어요
        수도: 도쿄
        언어: 일본어
        음식: 스시와 라멘
        통화: 엔
    """
    },
    {
        "country": "대한민국에 대해서 어떻게 알고 있나요?",
        "answer": """
            저는 이렇게 알고 있어요
            수도: 서울
            언어: 한국어
            음식: 김치와 불고기
            통화: 원
        """
    },
    {
    "country": "이탈리아에 대해서 어떻게 알고 있나요?",
    "answer": """
        저는 이렇게 알고 있어요
        수도: 로마
        언어: 이탈리아어
        음식: 피자와 파스타
        통화: 유로
    """
    }
]

# %%
length_prompt = PromptTemplate(
    input_variables=["country","answer"],
    template="""
        Human: {country}에 대해서 어떻게 알고 있어요 ? \n
        AI : {answer}
        """
)

example_prompt = ChatPromptTemplate.from_messages([
    ("human","{country}에 대해서 어떻게 알고 있어요 ?"),
    ("ai","{answer}"),
])

example_selector =LengthBasedExampleSelector(
    examples=examples,
    example_prompt=length_prompt,
    max_length=200
)

fewshot_prompt = FewShotChatMessagePromptTemplate(
    example_selector = example_selector,
    example_prompt=example_prompt
)

final_prompt = ChatPromptTemplate.from_message([
    ("system","당신은 지리학 전문가입니다."),
    fewshot_prompt,
    ("human","{country}에 대해서 어떻게 알고 있나요 ?")
])
