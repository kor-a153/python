# %%
score = int(input ("점수를 입력하세요. ex)60\n"))
# Out:
# 점수를 입력하세요. ex)60
#  80

# %%
grade = ''

if score > 90:
    grade = 'A'
elif score > 80:
    grade ='B'
elif score > 70:
    grade ='C'
else:
    grade ='F'

print(grade)
# Out:
# C

# %%
"합격" if score > 60 else "불합격"
# Out:
# '합격'

# %%
if score % 2 == 0:
    print ("짝수")
else:
    print("홀수")
# Out:
# 짝수
