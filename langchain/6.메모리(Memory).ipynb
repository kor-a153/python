# %%
from dotenv import load_dotenv
import os
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts.prompt import PromptTemplate
from langchain_core.prompts.chat import ChatPromptTemplate

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])
# Out:
# sk-proj-ktAbTJ1mXZ2V

# %%
chat = ChatOpenAI(temperature=0)

# %%
chat.invoke("게는 누구의 후손이니 ?")

# %% [markdown]
# ## ConversationBufferMemory

# %%
from langchain_classic.memory import ConversationBufferMemory

# %%
memory = ConversationBufferMemory()
# Out:
# C:\Users\yuo02\AppData\Local\Temp\ipykernel_6720\995385594.py:1: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory()

# %%
memory.save_context(
    {"input":"Hi"},
    {"output":"How are you?"}
)

# %%
print(memory.load_memory_variables({}))
# Out:
# {'history': 'Human: Hi\nAI: How are you?'}

# %%
print((type)memory)
# Out:
#   Cell In[12], line 1
#     print((type)memory)
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ## return_message=True
#     - history 객체에 AIMessage, HumanMessage로 저장하게 만든다.

# %%
memory = ConversationBufferMemory(return_messages=True)

# %%
memory.save_context(
    {"input":"HI"}
    {"output":""}
)
# Out:
#   Cell In[14], line 2
#     {"input":"HI"}
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ## 문제점

# %%
chat = ChatOpenAI(temperature=0.1)

# %% [markdown]
# ## 체인

# %%
from langchain_classic.chain import ConversationChain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from langchain_classic.chain import ConversationChain
#
# ModuleNotFoundError: No module named 'langchain_classic.chain'

# %%
llm = ChatOpenAI(temperature=0.1)
memory = ConversationBufferMemory(return_message=True)

chain = ConversationChain(llm=llm,memory=memory)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 llm = ChatOpenAI(temperature=0.1)
#       2 memory = ConversationBufferMemory(return_message=True)
#       3
# ----> 4 chain = ConversationChain(llm=llm,memory=memory)
#
# NameError: name 'ConversationChain' is not defined

# %%
chain.invoke("sksms tpghks")

# %%
memory.save_context({"input": "1"}, {"output": "1"})
memory.save_context({"input": "2"}, {"output": "2"})
memory.save_context({"input": "3"}, {"output": "3"})
memory.save_context({"input": "4"}, {"output": "4"})
memory.save_context({"input": "5"}, {"output": "5"})
memory.save_context({"input": "6"}, {"output": "6"})

# %%
## ConversationSummaryMemory

# %%
from langchain_classic.memory import ConversationSummaryMemory

# %% [markdown]
# ## ConversationSummaryBufferMemory
# - 요약본의 토큰수를 제한하는 메모리

# %% [markdown]
# ## ConversationKGMemory

# %% [markdown]
# ## LCEL 방법 권장

# %%
# MessagesPlaceholder: 프롬프트 안에 “대화 기록”을 끼워 넣는 자리표시 역할
# InMemoryChatMessageHistory: 대화 내용을 메모리에 저장
# RunnableWithMessageHistory: 체인 + 메모리 + 프롬프트를 자동으로 연결해주는 랩퍼
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

# %%
chat = ChatOpenAI(temperature = 0.1)
