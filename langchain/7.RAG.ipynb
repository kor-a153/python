# %%
chat = ChatOpenAI(temperature= 0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 chat = ChatOpenAI(temperature= 0.1)
#
# NameError: name 'ChatOpenAI' is not defined

# %%
base_path
